# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("data/Food_Production.csv", index_col=0)

# %%
display(df)
# Out:
#                      Land use change  Animal Feed  Farm  Processing  \
# Food product
# Wheat & Rye (Bread)              0.1          0.0   0.8         0.2
# Maize (Meal)                     0.3          0.0   0.5         0.1
# Barley (Beer)                    0.0          0.0   0.2         0.1
# Oatmeal                          0.0          0.0   1.4         0.0
# Rice                             0.0          0.0   3.6         0.1
# Potatoes                         0.0          0.0   0.2         0.0
# Cassava                          0.6          0.0   0.2         0.0
# Cane Sugar                       1.2          0.0   0.5         0.0
# Beet Sugar                       0.0          0.0   0.5         0.2
# Other Pulses                     0.0          0.0   1.1         0.0
# Peas                             0.0          0.0   0.7         0.0
# Nuts                            -2.1          0.0   2.1         0.0
# Groundnuts                       0.4          0.0   1.4         0.4
# ...

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Land use per kilogram (m² per kilogram)', y=df.index, data=df)
plt.xlabel('Land use per kilogram (m² per kilogram)')
plt.ylabel('Food Product')
plt.title('Land Use per Kilogram of Food Product')
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(12, 8))

color = 'tab:blue'
ax1.set_xlabel('Food Product')
ax1.set_ylabel('Freshwater withdrawals per kilogram (liters per kilogram)', color=color)
ax1.bar(df.index, df['Freshwater withdrawals per kilogram (liters per kilogram)'], color=color, alpha=0.6, label='Freshwater withdrawals per kilogram')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_xticklabels(df.index, rotation=90)

ax2 = ax1.twinx()  
color = 'tab:green'
ax2.set_ylabel('Land use per kilogram (m² per kilogram)', color=color)
ax2.plot(df.index, df['Land use per kilogram (m² per kilogram)'], color=color, marker='o', label='Land use per kilogram')
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  
plt.title('Freshwater Withdrawals and Land Use per Kilogram of Food Product')
plt.show()
# Out:
# /var/folders/zq/s6yvpzhn0wdctd409d0vs5dc0000gn/T/ipykernel_96706/1336887521.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(df.index, rotation=90)

# %%
fig, ax1 = plt.subplots(figsize=(12, 8))

color = 'tab:green'
ax1.set_xlabel('Food Product')
ax1.set_ylabel('Greenhouse gas emissions per 100g protein (kgCO₂eq per 100g protein)', color=color)
ax1.bar(df.index, df['Greenhouse gas emissions per 100g protein (kgCO₂eq per 100g protein)'], color=color, alpha=0.6, label='Greenhouse gas emissions per 100g protein')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_xticklabels(df.index, rotation=90)

ax2 = ax1.twinx()  
color = 'tab:blue'
ax2.set_ylabel('Land use per 100g protein (m² per 100g protein)', color=color)
ax2.plot(df.index, df['Land use per 100g protein (m² per 100g protein)'], color=color, marker='o', label='Land use per 100g protein')
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  
plt.title('Greenhouse Gas Emissions and Land Use per 100g Protein of Food Product')
plt.show()
# Out:
# /var/folders/zq/s6yvpzhn0wdctd409d0vs5dc0000gn/T/ipykernel_96706/2789643076.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(df.index, rotation=90)

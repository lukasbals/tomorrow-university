# %% [markdown]
# # Initial Data Exploration

# %%
import pandas as pd

yield_tables = pd.read_csv("../data/raw/yield_tables.csv", sep=";")
yield_tables_meta = pd.read_csv("../data/raw/yield_tables_meta.csv", sep=";")

# %%
yield_tables.describe()
# Out:
#                  id   yield_class           age  dominant_height  \
# count  14398.000000  14398.000000  14398.000000      8825.000000
# mean     125.767954      7.899590     79.438741        22.114483
# std       65.677997      5.677468     48.892472        22.425561
# min        1.000000      0.000000      4.000000         0.000000
# 25%       89.000000      4.000000     40.000000        15.000000
# 50%      148.000000      6.000000     70.000000        21.900000
# 75%      180.000000     11.000000    110.000000        28.800000
# max      213.000000     36.000000    300.000000      1919.000000
#
#        average_height          dbh        taper  trees_per_ha   basal_area  \
# count     9340.000000  9113.000000  4425.000000   9255.000000  9511.000000
# mean        20.367438    26.342264     0.455306   1166.835475    33.763197
# std          8.747435    14.288931     0.073344   2194.385171    13.796179
# min          0.000000   -36.400000     0.066000      0.000000     0.000000
# ...

# %%
yield_tables_meta.head()
# Out:
#    id               title country_codes     type  \
# 0   1  Fichte Hochgebirge         AT,DE  dgz_100
# 1   2       Fichte Bayern         AT,DE  dgz_100
# 2   3        Fichte Bruck         AT,DE  dgz_100
# 3   4       Fichte Weitra         AT,DE  dgz_100
# 4   5           Tanne NWD         AT,DE  dgz_100
#
#                                               source  \
# 0  1975, Julius Marschall: Hilfstafeln für die Fo...
# 1  1975, Julius Marschall: Hilfstafeln für die Fo...
# 2  1975, Julius Marschall: Hilfstafeln für die Fo...
# 3  1975, Julius Marschall: Hilfstafeln für die Fo...
# 4  1975, Julius Marschall: Hilfstafeln für die Fo...
#
#                                                 link  yield_class_step  \
# 0  https://www.avbuch-shop.at/landwirtschaft/lehr...               1.0
# 1  https://www.avbuch-shop.at/landwirtschaft/lehr...               1.0
# 2  https://www.avbuch-shop.at/landwirtschaft/lehr...               1.0
# ...

# %%
print(f"Null values on tree type: {yield_tables_meta['tree_type'].isna().sum()}")
print(f"Null values on title (gives indication about tree species): {yield_tables_meta['title'].isna().sum()}")
# Out:
# Null values on tree type: 0
# Null values on title (gives indication about tree species): 0
